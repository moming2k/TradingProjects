# %%
import time
import urllib
import urllib2
import datetime
from StringIO import StringIO
from BeautifulSoup import BeautifulSoup

import pandas as pd


def get(url, data_list=None, max_try=3):
    if data_list:
        url = "{}?{}".format(url, urllib.urlencode(data_list))
    query = urllib2.Request(url)
    current_try = 0
    while current_try < max_try:
        try:
            response = urllib2.urlopen(query)
            html = response.read()
            response.close()
            return html
        except Exception, e:
            return None
    raise Exception("Cannot open page {}".format(url))

# %%
url = 'http://www.hkhorsedb.com/cseh/passodds.php'
html = get(url)

# %%
soup = BeautifulSoup(html)

# %%
tr_list = soup.findAll('table')[15].findAll('tr')[1:]

# %%
detail_date = tr_list[1].findAll('td')[0].text

# %%
target_url = 'http://www.hkhorsedb.com/cseh/poddsleftxml.php'
date_info = ''.join(detail_date.split('-'))
query_data = [('rdate', date_info),
              ('vrecno', 1),
              ('pcode', 1)]

query_result = get(target_url, query_data)

# %%
soup.findAll('table')[1].findAll('tr')[1].findAll('td')[17].findAll('font')
# Out:
# [<font color="red"><b>4.7</b></font>]

# %%
date_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-52ee30625a2d> in <module>()
# ----> 1 date_info
#
# NameError: name 'date_info' is not defined

# %%
html = '''<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN"><html xmlns="http://www.w3.org/1999/xhtml"><head><title>HongKong Horse Databases by infomaker production</title>
<meta http-equiv="Content-Type" content="text/html; charset=big5" />
<meta content="MSHTML 6.00.2462.0" name="GENERATOR" /></head>
<body leftmargin="0" topmargin="0" rightmargin="0">
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style>A:hover {
        COLOR: red
}
.clsMenuItem {
        FONT-SIZE: 10pt; FONT-FAMILY: Arial; TEXT-DECORATION: none
}
A.clsMenuItem {
        COLOR: blue
}
P.clsMenuTitle {
        FONT-WEIGHT: ; FONT-SIZE: 11pt; FONT-FAMILY:  Arial, Helvetica, sans-serif;
}
P.clsLastTitle {
        FONT-WEIGHT: bold ; FONT-SIZE: 9pt; FONT-FAMILY: 細明體;
}
P.clsLastItem {
        FONT-SIZE: 9pt; FONT-FAMILY: 細明體;
}
P.clsnumItem {
        FONT-WEIGHT:  ; FONT-SIZE: 9pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
P.clsnumItem1 {
        FONT-WEIGHT:  ; FONT-SIZE: 8pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
P.clsnumtitle {
        FONT-WEIGHT: bold ; FONT-SIZE: 9pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
.QINHEADER {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-WEIGHT: bolder; FONT-SIZE: 0.3cm; PADDING-BOTTOM: 2px; BORDER-LEFT: black 1px solid; WIDTH: 25px; COLOR: white; PADDING-TOP: 2px; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.QINHEADERCC {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-WEIGHT: bolder; FONT-SIZE: 0.3cm; PADDING-BOTTOM: 2px; BORDER-LEFT: black 1px solid; WIDTH: 25px; COLOR: white; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; PADDING-LEFT: 4px; FONT-WEIGHT: bolder; FONT-SIZE: 12px; PADDING-BOTTOM: 3px; BORDER-LEFT: black 1px solid; COLOR: white; PADDING-TOP: 3px; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header1 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #ffcccc; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Footer {
        BORDER-RIGHT: black 1px white; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #CEE3F6; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header4 {
        BORDER-RIGHT: white 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #ffffcc; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header10 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #99ccff; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header11 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #99ccff; TEXT-ALIGN: center; FONT-VARIANT: normal
}
 
.Chin {
        FONT-WEIGHT: normal; FONT-SIZE: 12px; FONT-FAMILY: 'Arial'
}
.GridData {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDataT {
        PADDING-RIGHT: 2px; FONT-SIZE: 11px; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDatadrop20 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid ; FONT-WEIGHT: bold ; PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #2EAB00; TEXT-ALIGN: right
}
.GridDatadrop50 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;FONT-WEIGHT: bold ;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right
}
.WGridDatadrop20 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid ; FONT-WEIGHT: bold ; PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #2EAB00; TEXT-ALIGN: right ;FONT-SIZE: 17px;
}
.WGridDatadrop50 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;FONT-WEIGHT: bold ;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right;FONT-SIZE: 17px;
}
.GridData1 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #f5efe8; TEXT-ALIGN: right
}
.GridData2 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDatafav {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: black; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #FF9900; TEXT-ALIGN: right
}
.GridDatafontdrop0 {
        FONT-WEIGHT: bold; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #3ADF00; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #ffffff; TEXT-ALIGN: right
}
.GridDatafontdrop20 {
        FONT-WEIGHT: bold; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #3ADF00; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #3ADF00; TEXT-ALIGN: right
}
.GridDatafontdrop50 {
         PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #8A4B08; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right
}
.GridDatah1 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #FFA2A2; TEXT-ALIGN: right
}
.GridDatah2 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #FF9900; TEXT-ALIGN: right
}
.GridDatac {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #99CCFF; TEXT-ALIGN: right
}
        }
.Header2 {
        BORDER-RIGHT: #d8bfa5 1px; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-WEIGHT: bolder; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header3 {
        BORDER-RIGHT: #d8bfa5 1px; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header40 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 15px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: white; TEXT-ALIGN: center
}
.Header20 {
        BORDER-RIGHT: #d8bfa5 1px;FONT-WEIGHT: bold; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'Microsoft JhengHei'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.table30 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #8A4B08; FONT-WEIGHT: bold; COLOR :#FFFFFF;
}
.table20 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #298A08; FONT-WEIGHT: bold; COLOR :#FFFFFF;
}
.table10 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #BDBDBD; FONT-WEIGHT: bold; COLOR :#000000;
}
.tablered { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #99ccff; FONT-WEIGHT: bold; COLOR :#000000;
}
.tableblue { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #ffcccc; FONT-WEIGHT: bold; COLOR :#000000;
}
.qintable10 {  BORDER-bottom: black 1px solid;BORDER-top: black 1px solid ;BORDER-left: black 1px solid;BORDER-RIGHT: black 1px solid; BACKGROUND-COLOR: #FFFFFF; FONT-SIZE: 17px; FONT-FAMILY: 'Arial' ;; TEXT-ALIGN: right;
}
.pqintable10 {BORDER-top: black 1px solid ; BORDER-bottom: black 1px solid;BORDER-left: black 1px solid;BORDER-RIGHT: black 1px solid; BACKGROUND-COLOR: #FFFFFF; FONT-SIZE: 17px; FONT-FAMILY: 'Arial' ;; TEXT-ALIGN: left;
}
input.commonButton {
  font-family: Verdana, Arial, Helvetica, sans-serif;
  font-size: 13px;
/*  font-weight: bold;
  text-transform: uppercase; */
  color: #000000;
  background-color: #eeeeee;
  background-image: url(../cseh/themes/Somara-XP/style/btn_bg.gif);
  border: none;
}
input[disabled].commonButton,
input[disabled].commonButton:hover,
input[disabled].commonButton:active {
  text-decoration: none;
  font-weight: bold;
  color: #999999;
  border: 2px solid #cccccc;
  background-color: #eeeeee;
}
input[disabled] {
  color: #999999;
  background-color: #eeeeee;
}
input.commonButton {
  width: 115px;
  height: 22px;
}
        </style>
<script language="JavaScript" src="../js/newwin.js"></script>
<!-- INCLUDE START: STANDARD HEADER --><link href="../js/style.css" type="text/css" rel="stylesheet" />
<script language="JavaScript" type="text/javascript">
&lt;!--
     NS4 = (document.layers);
     IE4 = (document.all);
    ver4 = (NS4 || IE4);
         IE5 = (IE4 &amp;&amp; navigator.appVersion.indexOf("5.")!=-1);
   isMac = (navigator.appVersion.indexOf("Mac") != -1);
  isMenu = (NS4 || (IE4 &amp;&amp; !isMac) || (IE5 &amp;&amp; isMac));
function popUp(){return};
function popDown(){return};
if (!ver4) event=null;
//--&gt;
</script>
<div><!--<div style="position: absolute; top: 8px; padding-top: 0px; margin-top: 0px">--><meta http-equiv="Expires" content="0" />
<meta http-equiv="Pragma" content="no-cache" />
<script language="JavaScript">
function changePage(obj) {
    i = obj.url.selectedIndex;
    self.location = obj.url.options[i].value;
    }
</script>
<align="center">
    <table width="100%" border="0" cellspacing="1" cellpadding="0" bgcolor="#D6DFF7">
    <tbody><tr>
   <form></form>
    <td width="50%" class="Header3">
2016-09-28    </td>
    <td width="40%">
    
</td><td><a href="poddsleftxml.php?vrecno=1&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/red1.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=2&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue2.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=3&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue3.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=4&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue4.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=5&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue5.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=6&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue6.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=7&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue7.gif" border="0" /></a></td><td><a href="poddsleftxml.php?vrecno=8&amp;rdate=28092016&amp;pcode=1"><img src="../images/odds/blue8.gif" border="0" /></a></td>   
    <td width="50%" align="center">
<select name="url" size="1" onchange="changePage(this.form)"><option>-----------</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=1" selected="">各場獨贏</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=2">連贏及位置</option>    <option value="poddsleftxml.php?vrecno=1&amp;textfield=&amp;rdate=28092016&amp;pcode=3">獨贏走勢</option>    <option value="poddsleftxml.php?vrecno=1&amp;textfield=&amp;rdate=28092016&amp;pcode=4">位置走勢</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=5">40分鐘走勢圖</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=6">隔夜賠率</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=7">孖寶</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=8">賠率變化</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=9">大注追蹤</option>    <option value="poddsleftxml.php?rdate=28092016&amp;vrecno=1&amp;pcode=10">CC 76</option></select></td>   </tr></tbody></table><link rel="StyleSheet" href="themes/newtheme/style/style.css" type="text/css" />                        
<title>HongKong Horse Databases by infomaker production</title>
<meta http-equiv="Content-Type" content="text/html; charset=big5" />
<meta content="MSHTML 6.00.2462.0" name="GENERATOR" />
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style type="text/css">A:link {
        COLOR: blue; TEXT-DECORATION: none
}
A:hover {
        COLOR: #ff0000
}
</style>
<style>A:hover {
        COLOR: red
}
.clsMenuItem {
        FONT-SIZE: 10pt; FONT-FAMILY: Arial; TEXT-DECORATION: none
}
A.clsMenuItem {
        COLOR: blue
}
P.clsMenuTitle {
        FONT-WEIGHT: ; FONT-SIZE: 11pt; FONT-FAMILY:  Arial, Helvetica, sans-serif;
}
P.clsLastTitle {
        FONT-WEIGHT: bold ; FONT-SIZE: 9pt; FONT-FAMILY: 細明體;
}
P.clsLastItem {
        FONT-SIZE: 9pt; FONT-FAMILY: 細明體;
}
P.clsnumItem {
        FONT-WEIGHT:  ; FONT-SIZE: 9pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
P.clsnumItem1 {
        FONT-WEIGHT:  ; FONT-SIZE: 8pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
P.clsnumtitle {
        FONT-WEIGHT: bold ; FONT-SIZE: 9pt; FONT-FAMILY: Arial, Helvetica, sans-serif;
}
.QINHEADER {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-WEIGHT: bolder; FONT-SIZE: 0.3cm; PADDING-BOTTOM: 2px; BORDER-LEFT: black 1px solid; WIDTH: 25px; COLOR: white; PADDING-TOP: 2px; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.QINHEADERCC {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-WEIGHT: bolder; FONT-SIZE: 0.3cm; PADDING-BOTTOM: 2px; BORDER-LEFT: black 1px solid; WIDTH: 25px; COLOR: white; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; PADDING-LEFT: 4px; FONT-WEIGHT: bolder; FONT-SIZE: 12px; PADDING-BOTTOM: 3px; BORDER-LEFT: black 1px solid; COLOR: white; PADDING-TOP: 3px; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #005094; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header1 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #ffcccc; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Footer {
        BORDER-RIGHT: black 1px white; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #CEE3F6; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header4 {
        BORDER-RIGHT: white 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #ffffcc; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header10 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #99ccff; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header11 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: white 1px solid; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 3px; BORDER-LEFT: white 1px solid; COLOR: black; PADDING-TOP: 1px; BORDER-BOTTOM: white 1px solid; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #99ccff; TEXT-ALIGN: center; FONT-VARIANT: normal
}
 
.Chin {
        FONT-WEIGHT: normal; FONT-SIZE: 12px; FONT-FAMILY: 'Arial'
}
.GridData {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDataT {
        PADDING-RIGHT: 2px; FONT-SIZE: 11px; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDatadrop20 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid ; FONT-WEIGHT: bold ; PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #2EAB00; TEXT-ALIGN: right
}
.GridDatadrop50 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;FONT-WEIGHT: bold ;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right
}
.WGridDatadrop20 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid ; FONT-WEIGHT: bold ; PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #2EAB00; TEXT-ALIGN: right ;FONT-SIZE: 17px;
}
.WGridDatadrop50 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid;FONT-WEIGHT: bold ;PADDING-RIGHT: 2px; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: white; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right;FONT-SIZE: 17px;
}
.GridData1 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #f5efe8; TEXT-ALIGN: right
}
.GridData2 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: white; TEXT-ALIGN: right
}
.GridDatafav {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: black; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #FF9900; TEXT-ALIGN: right
}
.GridDatafontdrop0 {
        FONT-WEIGHT: bold; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #3ADF00; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #ffffff; TEXT-ALIGN: right
}
.GridDatafontdrop20 {
        FONT-WEIGHT: bold; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #3ADF00; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #3ADF00; TEXT-ALIGN: right
}
.GridDatafontdrop50 {
         PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 11px; COLOR: #8A4B08; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: #8A4B08; TEXT-ALIGN: right
}
.GridDatah1 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #FFA2A2; TEXT-ALIGN: right
}
.GridDatah2 {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #FF9900; TEXT-ALIGN: right
}
.GridDatac {
        BORDER-RIGHT: black 1px solid; BORDER-TOP: black 1px solid; FONT-SIZE: 11px; BORDER-LEFT: black 1px solid; COLOR: black; BORDER-BOTTOM: black 1px solid; FONT-FAMILY: 'Arial'; BACKGROUND-COLOR: #99CCFF; TEXT-ALIGN: right
}
        }
.Header2 {
        BORDER-RIGHT: #d8bfa5 1px; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-WEIGHT: bolder; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header3 {
        BORDER-RIGHT: #d8bfa5 1px; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'MS Sans Serif'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.Header40 {
        BORDER-RIGHT: black 1px solid; PADDING-LEFT: 4px;PADDING-RIGHT: 2px; FONT-SIZE: 15px; PADDING-BOTTOM: 3px;  PADDING-TOP: 3px; FONT-FAMILY: Arial; BACKGROUND-COLOR: white; TEXT-ALIGN: center
}
.Header20 {
        BORDER-RIGHT: #d8bfa5 1px;FONT-WEIGHT: bold; BORDER-TOP: #d8bfa5 1px; PADDING-LEFT: 4px; FONT-SIZE: 13px; PADDING-BOTTOM: 4px; BORDER-LEFT: #d8bfa5 1px; COLOR: black; PADDING-TOP: 3px; BORDER-BOTTOM: #d8bfa5 1px; FONT-FAMILY: 'Microsoft JhengHei'; BACKGROUND-COLOR: #d8bfa5; TEXT-ALIGN: center; FONT-VARIANT: normal
}
.table30 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #8A4B08; FONT-WEIGHT: bold; COLOR :#FFFFFF;
}
.table20 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #298A08; FONT-WEIGHT: bold; COLOR :#FFFFFF;
}
.table10 { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #BDBDBD; FONT-WEIGHT: bold; COLOR :#000000;
}
.tablered { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #99ccff; FONT-WEIGHT: bold; COLOR :#000000;
}
.tableblue { border: 1px solid #ffffff; border-width:1px; width:25px; BACKGROUND-COLOR: #ffcccc; FONT-WEIGHT: bold; COLOR :#000000;
}
.qintable10 {  BORDER-bottom: black 1px solid;BORDER-top: black 1px solid ;BORDER-left: black 1px solid;BORDER-RIGHT: black 1px solid; BACKGROUND-COLOR: #FFFFFF; FONT-SIZE: 17px; FONT-FAMILY: 'Arial' ;; TEXT-ALIGN: right;
}
.pqintable10 {BORDER-top: black 1px solid ; BORDER-bottom: black 1px solid;BORDER-left: black 1px solid;BORDER-RIGHT: black 1px solid; BACKGROUND-COLOR: #FFFFFF; FONT-SIZE: 17px; FONT-FAMILY: 'Arial' ;; TEXT-ALIGN: left;
}
input.commonButton {
  font-family: Verdana, Arial, Helvetica, sans-serif;
  font-size: 13px;
/*  font-weight: bold;
  text-transform: uppercase; */
  color: #000000;
  background-color: #eeeeee;
  background-image: url(../cseh/themes/Somara-XP/style/btn_bg.gif);
  border: none;
}
input[disabled].commonButton,
input[disabled].commonButton:hover,
input[disabled].commonButton:active {
  text-decoration: none;
  font-weight: bold;
  color: #999999;
  border: 2px solid #cccccc;
  background-color: #eeeeee;
}
input[disabled] {
  color: #999999;
  background-color: #eeeeee;
}
input.commonButton {
  width: 115px;
  height: 22px;
}
        </style>
<script language="JavaScript" src="../js/newwin.js"></script>
<!-- INCLUDE START: STANDARD HEADER --><link href="../js/style.css" type="text/css" rel="stylesheet" />
<script language="JavaScript" type="text/javascript">
&lt;!--
     NS4 = (document.layers);
     IE4 = (document.all);
    ver4 = (NS4 || IE4);
         IE5 = (IE4 &amp;&amp; navigator.appVersion.indexOf("5.")!=-1);
   isMac = (navigator.appVersion.indexOf("Mac") != -1);
  isMenu = (NS4 || (IE4 &amp;&amp; !isMac) || (IE5 &amp;&amp; isMac));
function popUp(){return};
function popDown(){return};
if (!ver4) event=null;
//--&gt;
</script>
<div><!--<div style="position: absolute; top: 8px; padding-top: 0px; margin-top: 0px">-->
<style type="text/css">
&lt;!--
.style1 {font-family: 細明體, Courier New, Courier, mono}
.style2 {font-size: 12px}
.style3 {font-family: 細明體, Courier New, Courier, mono}
.style4 {font-size: 13px}
.style8 {font-size: 11px}
.style7 {color: red; font-size: 11px;font-weight: bold;}
.style5 {font-family: Arial, Helvetica, sans-serif}
.style6 {color: #336666; font-size: 15px;font-weight: bold;}
.style9 {color: #336666; font-size: 12px;font-weight: bold,font-family: 細明體, Courier New, Courier, mono;font-weight: bold;}
.style10 {color: #000000; font-size: 12px;font-weight: bold,font-family: 細明體, Courier New, Courier, mono;}
--&gt;
</style>
<table width="100%" border="0" cellpadding="0" cellspacing="1" bgcolor="#FF9933"><tbody><tr height="22"><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第1場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第2場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第3場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第4場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第5場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第6場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第7場</b></font></td><td style="TEXT-ALIGN: center" colspan="3" bgcolor="#FFE7CE"><font color="#000000"><b>第8場</b></font></td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 銀影大亨</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 22</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 鑽飾傳奇</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 7.65</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 感恩    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 43</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 全勝姿態</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 7.85</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 盛勢    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 35</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 瑰麗傳奇</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>4.7</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 乘勢好運</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 4.9</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">1</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 精氣神  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 33</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 吉利高  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 41</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 百戰百勝</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 退出</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 財政大臣</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 99</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勁駿皇駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 44</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 歡喜    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 14</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 非常堅  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 39</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 恆駿寶駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>2.7</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">2</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 雄心巨龍</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 43</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 哈哈笑  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 9.9</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 英姿茂盛</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 38</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勝利雄心</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.3</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 明多多  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.35</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 創意寶  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.75</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 綠色勁駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 11</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 愛寶    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 81</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">3</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 神舟小子</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 41</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 永恆光輝</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 4.35</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 珍珠有利</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 10</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 神電金剛</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 28</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 飛霞    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 12</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勁皇子  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 10</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 康樂神駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 6.45</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 超好玩  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 9.7</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">4</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 好健康  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 26</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 野外桃源</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.1</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 得利多  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 4.2</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 由心出發</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 18</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 元豐泰  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 27</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 常拼常勝</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>3.4</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 凱倫之寶</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 9.0</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 大運舞台</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 99</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">5</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 川河寶駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 4.4</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 識飛    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>3.95</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 育馬妙星</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 10</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 日出彩虹</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 退出</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 樂趣    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.15</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勇勝王  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 10</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 可愛寶  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.4</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 環保戰士</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 99</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">6</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 金滙龍華</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.85</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 神光輝耀</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.7</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 君子協定</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>2.55</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 信心出擊</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.8</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 永得米  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 99</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 富萬家  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 7.05</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 蓮花巨星</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 11</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 四千金  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 9.85</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">7</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 威利大大</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 31</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 萬醒仔  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 6.15</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 特獎    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 99</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 信是有緣</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 10</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 天狼星  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.05</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 和平開心</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 8.2</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 開心駿馬</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.6</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 滿載而來</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 97</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">8</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勁趣    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>2.95</b></font></td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 彩利    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 19</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 中華壹號</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 6.45</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 相中有你</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 11</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 牛魔王  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 30</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 劍凌雲  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 22</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 凱明神駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.05</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 開心有你</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 4.45</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">9</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 變出美麗</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 5.6</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 課課快  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 46</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 新添    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 42</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 魅力好漢</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 21</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 大將風速</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>3.45</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 八運    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 7.15</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 新妙星  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 51</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 舖舖旺  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 47</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">10</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 旅遊首席</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 22</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 掌握時機</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 23</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 喜得龍  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 36</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 非凡者  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 30</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 智能    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 11</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 駿擊快車</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 19</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 勝風    </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 49</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 綫路神駒</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 12</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">11</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 迎風飄揚</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 35</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 飛壹般  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 24</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 紅旗飛將</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 44</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 事必獲利</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> <font color="red"><b>1.9</b></font></td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 人生路  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 72</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 欖球鑽石</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 52</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 段段有  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 15</td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">12</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> 觀自在  </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> 13</td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">13</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td></tr><tr class="tiny1" height="22"><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td><td bgcolor="#FFE7CE" style="TEXT-ALIGN: center">14</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: left"> </td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: center"> </td></tr><tr class="tiny1" height="22"><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$19,391,633</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$22,017,944</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$23,819,219</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$27,430,453</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$28,458,463</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$34,167,949</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$37,900,771</td><td bgcolor="#FFFFFF" style="TEXT-ALIGN: right" colspan="3">$37,329,191</td></tr></tbody></table>
</div></align="center"></div></body></html>'''
